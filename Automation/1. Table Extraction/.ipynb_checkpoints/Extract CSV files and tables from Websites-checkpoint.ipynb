# %%
import pandas as pd
import requests

# %% [markdown]
# # Extracting Tables

# %%
url='https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)'

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %%
response=requests.get(url,headers=headers).text

# %%
simpsons=pd.read_html(response)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7264\3546153133.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   simpsons=pd.read_html(response)

# %%
simpsons[0]
# Out:
#    Season Episodes            Originally released                   \
#    Season Episodes Episodes.1      First released    Last released
# 0       1       13         13   December 17, 1989     May 13, 1990
# 1       2       22         22    October 11, 1990    July 11, 1991
# 2       3       24         24  September 19, 1991  August 27, 1992
# 3       4       22         22  September 24, 1992     May 13, 1993
# 4       5       22         22  September 30, 1993     May 19, 1994
# 5       6       25         25   September 4, 1994     May 21, 1995
# 6       7       25         25  September 17, 1995     May 19, 1996
# 7       8       25         25    October 27, 1996     May 18, 1997
# 8       9       25         25  September 21, 1997     May 17, 1998
# 9      10       23         23     August 23, 1998     May 16, 1999
# 10     11       22         22  September 26, 1999     May 21, 2000
# 11     12       21         21    November 1, 2000     May 20, 2001
# ...

# %% [markdown]
# # Read CSV from URL

# %%
df_premier=pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')

# %%
df_premier.rename(columns={'FTHG':'Home_Goals','FTAG':'Away_Games'},inplace=True)

# %%
df_premier
# Out:
#     Div        Date   Time          HomeTeam       AwayTeam  Home_Goals  \
# 0    E0  11/08/2023  20:00           Burnley       Man City           0
# 1    E0  12/08/2023  12:30           Arsenal  Nott'm Forest           2
# 2    E0  12/08/2023  15:00       Bournemouth       West Ham           1
# 3    E0  12/08/2023  15:00          Brighton          Luton           4
# 4    E0  12/08/2023  15:00           Everton         Fulham           0
# ..   ..         ...    ...               ...            ...         ...
# 375  E0  19/05/2024  16:00    Crystal Palace    Aston Villa           5
# 376  E0  19/05/2024  16:00         Liverpool         Wolves           2
# 377  E0  19/05/2024  16:00             Luton         Fulham           2
# 378  E0  19/05/2024  16:00          Man City       West Ham           3
# 379  E0  19/05/2024  16:00  Sheffield United      Tottenham           0
#
#      Away_Games FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...
